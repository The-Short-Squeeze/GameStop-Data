# %%
#pip install tweepy
import requests
import os
import json
import tweepy
import pandas as pd

# %%
# %run ./twitterapikey.ipynb

# %%
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

cursor = tweepy.Cursor(api.search, q="$GME", tweet_mode ="extended").items(1)
for i in cursor:
    print(i)
# Out:
# Status(_api=<tweepy.api.API object at 0x000002C6A186DB20>, _json={'created_at': 'Fri Jan 29 21:21:38 +0000 2021', 'id': 1355264866832027648, 'id_str': '1355264866832027648', 'full_text': 'RT @wallstreetbets_: Uncharted territory \n#wallstreetbets #WSB $GME $BB $BBBY $AMC $AMD $PLTR $PSTH $AAPL $TSLA $MSFT $NIO $BABA $INO $IPOE…', 'truncated': False, 'display_text_range': [0, 140], 'entities': {'hashtags': [{'text': 'wallstreetbets', 'indices': [42, 57]}, {'text': 'WSB', 'indices': [58, 62]}], 'symbols': [{'text': 'GME', 'indices': [63, 67]}, {'text': 'BB', 'indices': [68, 71]}, {'text': 'BBBY', 'indices': [72, 77]}, {'text': 'AMC', 'indices': [78, 82]}, {'text': 'AMD', 'indices': [83, 87]}, {'text': 'PLTR', 'indices': [88, 93]}, {'text': 'PSTH', 'indices': [94, 99]}, {'text': 'AAPL', 'indices': [100, 105]}, {'text': 'TSLA', 'indices': [106, 111]}, {'text': 'MSFT', 'indices': [112, 117]}, {'text': 'NIO', 'indices': [118, 122]}, {'text': 'BABA', 'indices': [123, 128]}, {'text': 'INO', 
# ...

# %%
#data pull removing retweets
num_of_tweets = 900
tweets = []
likes = []
time = []

for i in tweepy.Cursor(api.search, q="$GME -filter:retweets", tweet_mode ="extended", until = '2021-01-22').items(num_of_tweets):
    tweets.append(i.full_text)
    likes.append(i.favorite_count)
    time.append(i.created_at)
    
wsb_df = pd.DataFrame({
    'tweets': tweets
    ,'likes': likes
    ,'time': time
})
wsb_df.to_csv('twitter_data_1-22.csv')

# %%
#additional code to filter out retweets
#wsb_df = wsb_df[~wsb_df.tweets.str.contains("RT")]
#wsb_df

# %%
#data pull filtering out all retweets
num_of_tweets = 900
tweets = []
likes = []
time = []

for i in tweepy.Cursor(api.search, q="$GME", tweet_mode ="extended", until = '2021-01-29').items(num_of_tweets):
    tweets.append(i.full_text)
    likes.append(i.favorite_count)
    time.append(i.created_at)
    
wsb_df = pd.DataFrame({
    'tweets': tweets
    ,'likes': likes
    ,'time': time
})
wsb_df.to_csv('RT_twitter_data_1-29.csv')
