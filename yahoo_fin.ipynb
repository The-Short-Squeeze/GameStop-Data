# %%
# !pip3 install yahoo_fin

# %%
# !pip3 install requests_html
# Out:
# ...
#      |████████████████████████████████| 87 kB 3.9 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 64 kB 8.9 MB/s  eta 0:00:01
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=af1bfa22e4a4cd0bb5ec23318c484a6a539d201afcf8f25fff256c856f4b33e3
#   Stored in directory: /Users/seltsam/Library/Caches/pip/wheels/75/78/21/68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# ...
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24581 sha256=68a3e6f5060fe8a808276749afa6b2715041921470d1e3e19fa8d1f64d4b8c3a
#   Stored in directory: /Users/seltsam/Library/Caches/pip/wheels/e5/33/1f/68392720485b3ecf125a69e700baaab7624616deedea2fa6e2
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13486 sha256=8d70b201cbb7f8b4aee7875c38116e3112c33b84f3ffea782820758cd6337e68
#   Stored in directory: /Users/seltsam/Library/Caches/pip/wheels/a0/b8/b7/8c942b2c5be5158b874a88195116b05ad124bac795f6665e65
# ...

# %%
import ftplib
import io
import json
import pandas
import requests
import requests_html

# %%
from yahoo_fin import options

# %%
# Options expiration dates

nflx_dates = options.get_expiration_dates("GME")
nflx_dates
# Out:
# ['January 29, 2021',
#  'February 5, 2021',
#  'February 12, 2021',
#  'February 19, 2021',
#  'February 26, 2021',
#  'March 5, 2021',
#  'March 19, 2021',
#  'April 16, 2021',
#  'July 16, 2021',
#  'November 19, 2021',
#  'January 21, 2022',
#  'January 20, 2023']

# %%
# option chain for a single ticker and expiration date

chain = options.get_options_chain("GME")
chain
# Out:
# {'calls':           Contract Name        Last Trade Date  Strike  Last Price     Bid  \
#  0    GME210129C00000500  2021-01-26 3:53PM EST     0.5      141.13  142.35
#  1    GME210129C00001000  2021-01-26 3:47PM EST     1.0      147.10  141.85
#  2    GME210129C00001500  2021-01-26 1:54PM EST     1.5      119.00  141.30
#  3    GME210129C00002000  2021-01-26 3:56PM EST     2.0      147.08  140.80
#  4    GME210129C00002500  2021-01-26 2:20PM EST     2.5      118.15  140.30
#  ..                  ...                    ...     ...         ...     ...
#  119  GME210129C00180000  2021-01-26 3:59PM EST   180.0       22.75   20.50
#  120  GME210129C00185000  2021-01-26 3:59PM EST   185.0       22.00   20.45
#  121  GME210129C00190000  2021-01-26 3:59PM EST   190.0       19.93   19.50
#  122  GME210129C00195000  2021-01-26 3:59PM EST   195.0       18.85   18.35
#  123  GME210129C00200000  2021-01-26 3:59PM EST   200.0       18.30   18.25
#
# ...

# %%
# To show calls

chain["calls"]
# Out:
#           Contract Name        Last Trade Date  Strike  Last Price     Bid  \
# 0    GME210129C00000500  2021-01-26 3:53PM EST     0.5      141.13  142.35
# 1    GME210129C00001000  2021-01-26 3:47PM EST     1.0      147.10  141.85
# 2    GME210129C00001500  2021-01-26 1:54PM EST     1.5      119.00  141.30
# 3    GME210129C00002000  2021-01-26 3:56PM EST     2.0      147.08  140.80
# 4    GME210129C00002500  2021-01-26 2:20PM EST     2.5      118.15  140.30
# ..                  ...                    ...     ...         ...     ...
# 119  GME210129C00180000  2021-01-26 3:59PM EST   180.0       22.75   20.50
# 120  GME210129C00185000  2021-01-26 3:59PM EST   185.0       22.00   20.45
# 121  GME210129C00190000  2021-01-26 3:59PM EST   190.0       19.93   19.50
# 122  GME210129C00195000  2021-01-26 3:59PM EST   195.0       18.85   18.35
# 123  GME210129C00200000  2021-01-26 3:59PM EST   200.0       18.30   18.25
#
# ...

# %%
# To show puts

chain["puts"]
# Out:
#           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0    GME210129P00000500   2021-01-26 3:44PM EST     0.5        0.01   0.00
# 1    GME210129P00001000  2021-01-26 10:01AM EST     1.0        0.01   0.00
# 2    GME210129P00001500   2021-01-26 3:36PM EST     1.5        0.01   0.00
# 3    GME210129P00002000   2021-01-26 3:36PM EST     2.0        0.01   0.00
# 4    GME210129P00002500   2021-01-26 2:21PM EST     2.5        0.01   0.00
# ..                  ...                     ...     ...         ...    ...
# 119  GME210129P00180000   2021-01-26 3:29PM EST   180.0       61.56  59.00
# 120  GME210129P00185000   2021-01-26 3:45PM EST   185.0       66.91  63.35
# 121  GME210129P00190000   2021-01-26 3:56PM EST   190.0       67.50  67.35
# 122  GME210129P00195000   2021-01-26 3:27PM EST   195.0       72.35  72.40
# 123  GME210129P00200000   2021-01-26 3:58PM EST   200.0       79.78  76.50
#
# ...
